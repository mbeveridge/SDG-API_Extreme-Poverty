# %%
import http.client

conn = http.client.HTTPSConnection("api.apihighways.org")

conn.request("GET", "/query?sql=SELECT%20*%20FROM%206a6de0b8-e544-495a-93ab-e8bc3c59fb20")

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"data":[{"id":"AL","entity-name":"Albania","year":1988,"value-1":0.08,"value-2":0.08,"value-3":0,"_id":"AWI1QW9xvygDdRYIezOl"},{"id":"AL","entity-name":"Albania","year":1992,"value-1":0.31,"value-2":0.31,"value-3":0,"_id":"AWI1QW9xvygDdRYIezOp"},{"id":"AL","entity-name":"Albania","year":1994,"value-1":0.64,"value-2":0.64,"value-3":0,"_id":"AWI1QW9xvygDdRYIezOr"},{"id":"AL","entity-name":"Albania","year":1997,"value-1":1.79,"value-2":1.79,"value-3":0,"_id":"AWI1QW9xvygDdRYIezOu"},{"id":"AL","entity-name":"Albania","year":2004,"value-1":1.53,"value-2":1.53,"value-3":0,"_id":"AWI1QW9xvygDdRYIezO1"},{"id":"AO","entity-name":"Angola","year":1992,"value-1":46.01,"value-2":46.01,"value-3":0,"_id":"AWI1QW9yvygDdRYIezPH"},{"id":"AO","entity-name":"Angola","year":1995,"value-1":45.26,"value-2":45.26,"value-3":0,"_id":"AWI1QW9yvygDdRYIezPK"},{"id":"AO","entity-name":"Angola","year":1996,"value-1":45,"value-2":45,"value-3":45,"_id":"AWI1QW9yvygDdRYIezPL"},{"id":"AO","entity-name":"Angola","year":2001,"value-1":43.59,"value-2":43.59,"value-3":0,"_id":"AWI1QW9yvygDdRYIezPQ"},{"id":"AO","entity-name":"Angola","year":2005,"value-1":42.58,"value-2":42.58,"value-3":42.58,"_id":"AWI1QW9yvygDdRYIezPU"},{"id":"AO","entity-name":"Angola","year":2011,"value-1":30.08,"value-2":30.08,"value-3":30.08,"_id":"AWI1QW9yvygDdRYIezPa"},{"id":"AO","entity-name":"Angola","year":2012,"value-1":29.25,"value-2":29.25,"value-3":29.25,"_id":"AWI1QW9yvygDdRYIezPb"},{"id":"AM","entity-name":"Armenia","year":1984,"value-1":5.98,"value-2":5.98,"value-3":5.98,"_id":"AWI1QW9yvygDdRYIezPd"},{"id":"AM","entity-name":"Armenia","year":1985,"value-1":6.72,"value-2":6.72,"value-3":0,"_id":"AWI1QW9yvygDdRYIezPe"},{"id":"AM","entity-name":"Armenia","year":1988,"value-1":9.08,"value-2":9.08,"value-3":0,"_id":"AWI1QW9yvygDdRYIezPh"},{"id":"AM","entity-name":"Armenia","year":2001,"value-1":15.67,"value-2":15.67,"value-3":0,"_id":"AWI1QW9yvygDdRYIezPu"},{"id":"AM","entity-name":"Armenia","year":2002,"value-1":15.06,"value-2":15.06,"value-3":15.06,"_id":"AWI1QW9yvygDdRYIezPv"},{"id":"AM","entity-name":"Armenia","year":2010,"value-1":2.54,"value-2":2.54,"value-3":2.54,"_id":"AWI1QW9yvygDdRYIezP3"},{"id":"AZ","entity-name":"Azerbaijan","year":1986,"value-1":0.52,"value-2":0.52,"value-3":0,"_id":"AWI1QW9yvygDdRYIezP9"},{"id":"AZ","entity-name":"Azerbaijan","year":1991,"value-1":1.49,"value-2":1.49,"value-3":0,"_id":"AWI1QW9yvygDdRYIezQC"},{"id":"AZ","entity-name":"Azerbaijan","year":1997,"value-1":5.88,"value-2":5.88,"value-3":0,"_id":"AWI1QW9yvygDdRYIezQI"},{"id":"AZ","entity-name":"Azerbaijan","year":2000,"value-1":2.75,"value-2":2.75,"value-3":0,"_id":"AWI1QW9yvygDdRYIezQL"},{"id":"AZ","entity-name":"Azerbaijan","year":2002,"value-1":0,"value-2":0,"value-3":0,"_id":"AWI1QW9yvygDdRYIezQN"},{"id":"AZ","entity-name":"Azerbaijan","year":2004,"value-1":0,"value-2":0,"value-3":0,"_id":"AWI1QW9yvygDdRYIezQP"},{"id":"AZ","entity-name":"Azerbaijan","year":2006,"value-1":0.16,"value-2":0.16,"value-3":0,"_id":"AWI1QW9yvygDdRYIezQR"},{"id":"AZ","entity-name":"Azerbaijan","year":2012,"value-1":0.37,"value-2":0.37,"value-3":0.37,"_id":"AWI1QW9yvygDdRYIezQX"},{"id":"BD","entity-name":"Bangladesh","year":1989,"value-1":40.74,"value-2":40.74,"value-3":0,"_id":"AWI1QW9yvygDdRYIezQe"},{"id":"BD","entity-name":"Bangladesh","year":1990,"value-1":41.44,"value-2":41.44,"value-3":41.44,"_id":"AWI1QW9yvygDdRYIezQf"},{"id":"BD","entity-name":"Bangladesh","year":1993,"value-1":38.42,"value-2":38.42,"value-3":38.42,"_id":"AWI1QW9yvygDdRYIezQi"},{"id":"BD","entity-name":"Bangladesh","year":1995,"value-1":36.91,"value-2":36.91,"value-3":0,"_id":"AWI1QW9yvygDdRYIezQk"},{"id":"BD","entity-name":"Bangladesh","year":1996,"value-1":36.15,"value-2":36.15,"value-3":36.15,"_id":"AWI1QW9yvygDdRYIezQl"},{"id":"BD","entity-name":"Bangladesh","year":1998,"value-1":35.9,"value-2":35.9,"value-3":0,"_id":"AWI1QW9yvygDdRYIezQn"},{"id":"BD","entity-name":"Bangladesh","year":2000,"value-1":34.75,"value-2":34.75,"value-3":0,"_id": ...

# %%
import pandas as pd
# "If you add this code it might be useful in parsing the JSON into a Python dictionary" :
import json
j = json.loads(data)
print(j['data'][0])
# df = pd.DataFrame(j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-16fb1f606e80> in <module>()
#       2 # "If you add this code it might be useful in parsing the JSON into a Python dictionary" :
#       3 import json
# ----> 4 j = json.loads(data)
#       5 print(j['data'][0])
#       6 # df = pd.DataFrame(j)
#
# NameError: name 'data' is not defined
